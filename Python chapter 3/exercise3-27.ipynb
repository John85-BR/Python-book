# %%
from decimal import Decimal 
world_rate = 7975105156
world_rate_initial = 7975105156
year = 2022
increase = 0

print('year\t\tpopulation\t\t\tincreased')
print(f'{year:<4}\t\t{world_rate_2022:<10}\t\t\t0')
for i in range(101):
    year+=1
    increase = Decimal(f'{Decimal(world_rate)*Decimal(0.08):.0f}')
    world_rate+=increase
    
    print(f'{year:<4}\t\t{Decimal(world_rate):<10}\t\t\t{increase:<9}')
    
    if world_rate>=(world_rate_initial*2):
        print(f' In the year: {year:<4} the population increase the DOUBLE of 2022')
        
    if world_rate>=(world_rate_initial*4):
        print(f' In the year: {year:<4} the population increase the QUADRUPLE of 2022')
# Out:
# year		population			increased
# 2022		7975105156			0
# 2023		8613113568			638008412
# 2024		9302162653			689049085
# 2025		10046335665			744173012
# 2026		10850042518			803706853
# 2027		11718045919			868003401
# 2028		12655489593			937443674
# 2029		13667928760			1012439167
# 2030		14761363061			1093434301
# 2031		15942272106			1180909045
# 2032		17217653874			1275381768
#  In the year: 2032 the population increase the DOUBLE of 2022
# 2033		18595066184			1377412310
#  In the year: 2033 the population increase the DOUBLE of 2022
# 2034		20082671479			1487605295
#  In the year: 2034 the population increase the DOUBLE of 2022
# 2035		21689285197			1606613718
#  In the year: 2035 the population increase the DOUBLE of 2022
# 2036		23424428013			1735142816
#  In the year: 2036 the population increase the DOUBLE of 2022
# 2037		25298382254			1873954241
#  In the year: 2037 the population increase the DOUBLE of 2022
# 2038		27322252834			2023870580
# ...
