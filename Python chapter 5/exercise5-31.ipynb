# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import random
import seaborn as sns

# %%
rolls = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
sns.set_style('whitegrid')

# %%
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set(xlabel='Die Value', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Die Value'), Text(0, 0.5, 'Frequency')]

# %%
title = f'Rolling a coin {len(rolls):,} Times'
axes.set_title(title)
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set(xlabel='Die Value', ylabel='Frequency')  
axes.set_title(title)
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0  
    text_y = bar.get_height() 
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, 
              fontsize=11, ha='center', va='bottom')

# %%
# %recall 3

# %%
rolls = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
rolls = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
rolls = [random.randrange(1, 3) for i in range(20000)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
# %recall 6

# %%
title = f'Rolling a coin {len(rolls):,} Times'
axes.set_title(title)
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set(xlabel='Die Value', ylabel='Frequency')  
axes.set_title(title)
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0  
    text_y = bar.get_height() 
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, 
              fontsize=11, ha='center', va='bottom')

# %%
title = f'Rolling a coin {len(rolls):,} Times'
axes.set_title(title)
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set(xlabel='Die Value', ylabel='Frequency')  
axes.set_title(title)
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0  
    text_y = bar.get_height() 
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, 
              fontsize=11, ha='center', va='bottom')

# %%
# %recall 3

# %%
rolls = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
rolls = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
rolls = [random.randrange(1, 3) for i in range(200000)]
values, frequencies = np.unique(rolls, return_counts=True)

# %%
# %recall 6

# %%
title = f'Rolling a coin {len(rolls):,} Times'
axes.set_title(title)
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set(xlabel='Die Value', ylabel='Frequency')  
axes.set_title(title)
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0  
    text_y = bar.get_height() 
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, 
              fontsize=11, ha='center', va='bottom')

# %%
title = f'Rolling a coin {len(rolls):,} Times'
axes.set_title(title)
axes = sns.barplot(x=values, y=frequencies, palette='bright')
axes.set(xlabel='Die Value', ylabel='Frequency')  
axes.set_title(title)
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0  
    text_y = bar.get_height() 
    text = f'{frequency:,}\n{frequency / len(rolls):.3%}'
    axes.text(text_x, text_y, text, 
              fontsize=11, ha='center', va='bottom')
